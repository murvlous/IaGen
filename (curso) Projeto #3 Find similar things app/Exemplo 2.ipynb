# %%
# !pip install langchain

# %%
# !pip install Openai

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings()

# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')

# %%
print(df)
# Out:
#      Words
# 0   School
# 1  College
# 2      Car
# 3     Bike
# 4    Apple
# 5   Orange
# 6   Banana

# %%
df["embeddings"] = df["Words"].apply(lambda x: embeddings.embed_query(x))

# %%
df.to_csv("word_embeddings.csv")

# %%
new_df = pd.read_csv("word_embeddings.csv")
print(new_df)
# Out:
#    Unnamed: 0    Words                                         embeddings
# 0           0   School  [0.005603401404052665, 0.009245103139357013, -...
# 1           1  College  [0.008567630960204773, -0.009737508048176517, ...
# 2           2      Car  [-0.004958966229655546, -0.012322071811467243,...
# 3           3     Bike  [0.005475643575399977, -0.013620303763624603, ...
# 4           4    Apple  [0.01447704940326135, -0.003934278727982006, -...
# 5           5   Orange  [0.02067122263312988, -0.029222075283705507, 9...
# 6           6   Banana  [-0.013063486621720556, -0.020059987402906335,...

# %%
our_text = "mango"

# %%
text_embedding = embeddings.embed_query(our_text)

# %%
print (f"Our embeddings is {text_embedding}")
# Out:
# Our embeddings is [-0.00855598079575663, -0.02611894369773943, 0.00911156403688284, -0.02079841923347105, 0.005444714924846603, 0.009791336341603497, -0.033151974691939715, -0.018432288209788948, -0.004369497957388495, -0.03171399410016716, 0.0029985148448007535, 0.009013519990291305, -0.00408843832611534, 0.019857194896076274, -0.019556526734881566, 0.0043237444104640334, 0.030955785813115266, -0.004294330917089818, 0.012536570577489027, -0.02000099295525353, -0.0098305534014466, 0.0067192879961978326, -0.0011928696603865114, -0.01921664058252124, 0.00038461876608001354, 0.002536073634201005, 0.027766084425535256, -0.011797971286019941, 0.007993861533210321, 0.0066637294858207085, 0.043610007570133606, -0.0140791303059507, -0.006131023716648615, -0.00504927026210915, -0.008261848655982021, -0.0015997527098550789, -0.0025556823969531866, -0.011713000213591116, -0.0017893045487874242, -0.016144593168438092, 0.01358237405157292, -0.021425901504185888, -0.01824927215944607, -0.015817779
# ...

# %%
from openai.embeddings_utils import cosine_similarity

# %%
df["similarity_score"] = df["embeddings"].apply(lambda x: cosine_similarity(x, text_embedding))

# %%
df
# Out:
#      Words                                         embeddings  \
# 0   School  [0.005603401404052665, 0.009245103139357013, -...
# 1  College  [0.008567630960204773, -0.009737508048176517, ...
# 2      Car  [-0.004958966229655546, -0.012322071811467243,...
# 3     Bike  [0.005475643575399977, -0.013620303763624603, ...
# 4    Apple  [0.01447704940326135, -0.003934278727982006, -...
# 5   Orange  [0.02067122263312988, -0.029222075283705507, 9...
# 6   Banana  [-0.013063486621720556, -0.020059987402906335,...
#
#    similarity_score
# 0          0.772163
# 1          0.770248
# 2          0.769984
# 3          0.783859
# 4          0.802235
# 5          0.833235
# 6          0.886195

# %%
df.sort_values("similarity_score", ascending=False).head(10)
# Out:
#      Words                                         embeddings  \
# 6   Banana  [-0.013063486621720556, -0.020059987402906335,...
# 5   Orange  [0.02067122263312988, -0.029222075283705507, 9...
# 4    Apple  [0.01447704940326135, -0.003934278727982006, -...
# 3     Bike  [0.005475643575399977, -0.013620303763624603, ...
# 0   School  [0.005603401404052665, 0.009245103139357013, -...
# 1  College  [0.008567630960204773, -0.009737508048176517, ...
# 2      Car  [-0.004958966229655546, -0.012322071811467243,...
#
#    similarity_score
# 6          0.886195
# 5          0.833235
# 4          0.802235
# 3          0.783859
# 0          0.772163
# 1          0.770248
# 2          0.769984
